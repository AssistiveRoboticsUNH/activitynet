# %%
import yaml
import os 
import glob

# %%
def list_topics(metadata_path): 
    metadata= yaml.load(open(metadata_path, 'r'), Loader=yaml.FullLoader)

    topics={}
    topic_metadatas=metadata['rosbag2_bagfile_information']['topics_with_message_count']
    for topic_metadata in topic_metadatas:
        topic_name=topic_metadata['topic_metadata']['name']
        message_count=topic_metadata['message_count']
        topics[topic_name]=message_count
        
    return topics

# %%
bag_directory = '/media/ns/Seagate/oct25/madison/cam1/rosbag2_madison_s_25_1/rosbag2_madison_s_25_1' 
metadata_path= os.path.join(bag_directory, 'metadata.yaml')
topics=list_topics(metadata_path)
topics
# Out:
# {'/zed_data_recording/zed_node_data_recording/body_trk/skeletons': 1515,
#  '/zed_data_recording/zed_node_data_recording/left/image_rect_color': 1516}

# %%
for name,count in topics.items():
    print(name,count)
# Out:
# /zed_data_recording/zed_node_data_recording/body_trk/skeletons 1515
# /zed_data_recording/zed_node_data_recording/left/image_rect_color 1516

# %%
image_frame_topci_name= [name for name in topics.keys() if 'image' in name][0]
skeleton_topic_name= [name for name in topics.keys() if 'skeleton' in name][0]
number_of_frames=topics[image_frame_topci_name]

image_frame_topci_name, skeleton_topic_name , number_of_frames
# Out:
# ('/zed_data_recording/zed_node_data_recording/left/image_rect_color',
#  '/zed_data_recording/zed_node_data_recording/body_trk/skeletons',
#  1516)

# %%
dir="/media/ns/Seagate/oct18/"
metadata_files=glob.glob(dir+"/**/metadata.yaml", recursive=True)
# metadata_files

id=1
for metadata_file in metadata_files:
    
    if not 'cam4' in metadata_file:
        continue
    
    # print(metadata_file)
    
    cmd=f"ROS_DOMAIN_ID={id} python3 zed_sub.py --rosbag_path {metadata_file.replace('/metadata.yaml', '').strip()} &"
    id +=1
    print(cmd)
    
    topics=list_topics(metadata_file)
    # print(topics)
    # print(len(topics))
    # print("\n")
# Out:
# ROS_DOMAIN_ID=1 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/skylar/cam4/rosbag2_skylar_18_1/rosbag2_skylar_18_1 &
# ROS_DOMAIN_ID=2 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/skylar/cam4/rosbag2_skylar_18/rosbag2_skylar_18 &
# ROS_DOMAIN_ID=3 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/skylar/cam4/rosbag2_skylar_18_pill/rosbag2_skylar_18_pill &
# ROS_DOMAIN_ID=4 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/ashleigh/cam4/rosbag2_ashleigh_18/rosbag2_ashleigh_18 &
# ROS_DOMAIN_ID=5 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/ashleigh/cam4/rosbag2_ashleigh_18_pill/rosbag2_ashleigh_18_pill &
# ROS_DOMAIN_ID=6 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/ashleigh/cam4/rosbag2_ashleigh_18_1/rosbag2_ashleigh_18_1 &
# ROS_DOMAIN_ID=7 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/ashley/cam4/rosbag2_ashley/rosbag2_ashley &
# ROS_DOMAIN_ID=8 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/ashley/cam4/rosbag2_ashley_1/rosbag2_ashley_1 &
# ROS_DOMAIN_ID=9 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/lauren/cam4/rosbag2_lauren/rosbag2_lauren &
# ROS_DOMAIN_ID=10 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/lauren/cam4/rosbag2_lauren_1/rosbag2_lauren_1 &
# ROS_DOMAIN_ID=11 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/lauren/cam4/rosbag2_lauren_2/rosbag2_lauren_2 &

# %%
# Out:
# '/media/ns/Seagate/oct18/lauren/cam1/rosbag2_lauren_2/rosbag2_lauren_2'

# %%
id=3
f"ROS_DOMAIN_ID={id} python3 zed_sub.py --rosbag_path {metadata_file.replace('/metadata.yaml', '').strip()}"
# Out:
# 'ROS_DOMAIN_ID=3 python3 zed_sub.py --rosbag_path /media/ns/Seagate/oct18/lauren/cam1/rosbag2_lauren_2/rosbag2_lauren_2'

# %%
import subprocess
def play_ros2_bag(bag_file_path, loop=False):
    # Prepare the ros2 bag play command
    command = ["ros2", "bag", "play", bag_file_path]
    if loop:
        command.append("--loop")

    try:
        # Start playing the bag file
        print(f"Playing ROS 2 bag file: {bag_file_path}")
        process = subprocess.Popen(command)
        
        # Wait for the process to complete (or terminate it programmatically if desired)
        process.wait()

    except KeyboardInterrupt:
        print("Interrupted, stopping playback.")
        process.terminate()
        process.wait()  # Ensure the process ends

# %%
play_ros2_bag(bag_directory, loop=False)
# Out:
# Playing ROS 2 bag file: /media/ns/Seagate/oct25/madison/cam1/rosbag2_madison_s_25_1/rosbag2_madison_s_25_1
# stdin is not a terminal device. Keyboard handling disabled.[INFO] [1730217696.889596513] [rosbag2_storage]: Opened database '/media/ns/Seagate/oct25/madison/cam1/rosbag2_madison_s_25_1/rosbag2_madison_s_25_1/rosbag2_madison_s_25_1_0.db3' for READ_ONLY.
# [INFO] [1730217696.889647914] [rosbag2_player]: Set rate to 1
# [INFO] [1730217696.915305799] [rosbag2_player]: Adding keyboard callbacks.
# [INFO] [1730217696.915332704] [rosbag2_player]: Press SPACE for Pause/Resume
# [INFO] [1730217696.915342208] [rosbag2_player]: Press CURSOR_RIGHT for Play Next Message
# [INFO] [1730217696.915349851] [rosbag2_player]: Press CURSOR_UP for Increase Rate 10%
# [INFO] [1730217696.915357957] [rosbag2_player]: Press CURSOR_DOWN for Decrease Rate 10%
# [INFO] [1730217696.915784320] [rosbag2_storage]: Opened database '/media/ns/Seagate/oct25/madison/cam1/rosbag2_madison_s_25_1/rosbag2_madison_s_25_1/rosbag2_madison_s_25_1_0.db3' for READ_ONLY.

# %%
bag_directory
# Out:
# '/media/ns/Seagate/oct25/madison/cam1/rosbag2_madison_s_25_1/rosbag2_madison_s_25_1'

# %%
path='_'.join( bag_directory.split("/")[-4:] )
path
# Out:
# 'madison_cam1_rosbag2_madison_s_25_1_rosbag2_madison_s_25_1'

# %%
dir="/media/ns/Seagate/oct18/"
mp4files=glob.glob(dir+"/**/*.mp4", recursive=True)
mp4files, len(mp4files)
# Out:
# (['/media/ns/Seagate/oct18/skylar/cam2/rosbag2_skylar_18_1/rosbag2_skylar_18_1/skylar_cam2_rosbag2_skylar_18_1_rosbag2_skylar_18_1/zed.mp4',
#   '/media/ns/Seagate/oct18/skylar/cam2/rosbag2_skylar_18/rosbag2_skylar_18/skylar_cam2_rosbag2_skylar_18_rosbag2_skylar_18/zed.mp4',
#   '/media/ns/Seagate/oct18/skylar/cam2/rosbag2_skylar_18_pill/rosbag2_skylar_18_pill/skylar_cam2_rosbag2_skylar_18_pill_rosbag2_skylar_18_pill/zed.mp4',
#   '/media/ns/Seagate/oct18/ashleigh/cam2/rosbag2_ashleigh_18/rosbag2_ashleigh_18/ashleigh_cam2_rosbag2_ashleigh_18_rosbag2_ashleigh_18/zed.mp4',
#   '/media/ns/Seagate/oct18/ashleigh/cam2/rosbag2_ashleigh_18_pill/rosbag2_ashleigh_18_pill/ashleigh_cam2_rosbag2_ashleigh_18_pill_rosbag2_ashleigh_18_pill/zed.mp4',
#   '/media/ns/Seagate/oct18/ashleigh/cam2/rosbag2_ashleigh_18_1/rosbag2_ashleigh_18_1/ashleigh_cam2_rosbag2_ashleigh_18_1_rosbag2_ashleigh_18_1/zed.mp4',
#   '/media/ns/Seagate/oct18/toupload/lauren_cam1_rosbag2_lauren_1_rosbag2_lauren_1/zed.mp4',
#   '/media/ns/Seagate/oct18/toupload/ashley_cam1_rosbag2_ashley_rosbag2_ashley/zed.mp4',
#   '/media/ns/Seagate/oct18/toupload/skylar_cam1_rosbag2_skylar_18_rosbag2_skylar_18/zed.mp4',
#   '/media/ns/Seagate/oct18/toupload/skylar_cam1_rosbag2_skylar_18_pill_rosbag2_skylar_18_pill/zed.mp4',
#   '/media/ns/Seagate/oct18/toupload/lauren_cam1_rosbag2_lauren_rosbag2_lauren/zed.mp4',
#   '/media/ns/Seagate/oct18/toupload/skylar_cam1_rosbag2_skylar_18_1_rosbag2_skylar_18_1/zed.mp4',
#   '/media/ns/Seagate/oct18/toupload/lauren_cam1_rosbag2_lauren_2_rosbag2_lauren_2/zed.mp4',
#   '/media/ns/Seagate/oct18/toupload/ashleigh_cam1_rosbag2_ashleigh_18_1_rosbag2_ashleigh_18_1/zed.mp4',
#   '/media/ns/Seagate/oct18/toupload/ashleigh_cam1_rosbag2_ashleigh_18_rosbag2_ashleigh_18/zed.mp4',
#   '/media/ns/Seagate/oct18/toupload/ashleigh_cam1_rosbag2_ashleigh_18_pill_rosbag2_ashleigh_18_pill/zed.mp4',
#   '/media/ns/Seagate/oct18/toupload/ashley_cam1_rosbag2_ashley_1_rosbag2_ashley_1/zed.mp4',
#   '/media/ns/Seagate/oct18/ashley/cam2/rosbag2_ashley_1/rosbag2_ashley_1/ashley_cam2_rosbag2_ashley_1_rosbag2_ashley_1/zed.mp4',
#   '/media/ns/Seagate/oct18/lauren/cam2/rosbag2_lauren/rosbag2_lauren/lauren_cam2_rosbag2_lauren_rosbag2_lauren/zed.mp4',
#   '/media/ns/Seagate/oct18/lauren/cam2/rosbag2_lauren_1/rosbag2_lauren_1/lauren_cam2_rosbag2_lauren_1_rosbag2_lauren_1/zed.mp4',
#   '/media/ns/Seagate/oct18/lauren/cam2/rosbag2_lauren_2/rosbag2_lauren_2/lauren_cam2_rosbag2_lauren_2_rosbag2_lauren_2/zed.mp4'],
#  21)

# %%
for file in mp4files:
    file_path=file.replace('/zed.mp4', '').strip()
    if 'cam2' not in file_path:
        continue
    print(file_path)
    
    # os.system(f"mv {file_path} /media/ns/Seagate/oct18/toupload")
# Out:
# /media/ns/Seagate/oct18/skylar/cam2/rosbag2_skylar_18_1/rosbag2_skylar_18_1/skylar_cam2_rosbag2_skylar_18_1_rosbag2_skylar_18_1
# /media/ns/Seagate/oct18/skylar/cam2/rosbag2_skylar_18/rosbag2_skylar_18/skylar_cam2_rosbag2_skylar_18_rosbag2_skylar_18
# /media/ns/Seagate/oct18/skylar/cam2/rosbag2_skylar_18_pill/rosbag2_skylar_18_pill/skylar_cam2_rosbag2_skylar_18_pill_rosbag2_skylar_18_pill
# /media/ns/Seagate/oct18/ashleigh/cam2/rosbag2_ashleigh_18/rosbag2_ashleigh_18/ashleigh_cam2_rosbag2_ashleigh_18_rosbag2_ashleigh_18
# /media/ns/Seagate/oct18/ashleigh/cam2/rosbag2_ashleigh_18_pill/rosbag2_ashleigh_18_pill/ashleigh_cam2_rosbag2_ashleigh_18_pill_rosbag2_ashleigh_18_pill
# /media/ns/Seagate/oct18/ashleigh/cam2/rosbag2_ashleigh_18_1/rosbag2_ashleigh_18_1/ashleigh_cam2_rosbag2_ashleigh_18_1_rosbag2_ashleigh_18_1
# /media/ns/Seagate/oct18/ashley/cam2/rosbag2_ashley_1/rosbag2_ashley_1/ashley_cam2_rosbag2_ashley_1_rosbag2_ashley_1
# /media/ns/Seagate/oct18/lauren/cam2/rosbag2_lauren/rosbag2_lauren/lauren_cam2_rosbag2_lauren_rosbag2_lauren
# /media/ns/Seagate/oct18/lauren/cam2/rosbag2_lauren_1/rosbag2_lauren_1/lauren_cam2_rosbag2_lauren_1_rosbag2_lauren_1
# /media/ns/Seagate/oct18/lauren/cam2/rosbag2_lauren_2/rosbag2_lauren_2/lauren_cam2_rosbag2_lauren_2_rosbag2_lauren_2
