# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
import numpy as np

import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import glob
from tqdm import tqdm
from collections import OrderedDict, defaultdict
from IPython.display import clear_output
import time
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import glob

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
meta_txt='eating_data_info.txt'

#filename, eating/non-eating, start, end

with open(meta_txt, 'r') as f:
    lines=f.readlines()

eating=[]
non_eating=[]
for sid, line in enumerate(lines):
    if 'non-eating' in line:
        line=line.split()
        se=line[1].split('=')[1].split(',')
        s,e=int(se[0]),int(se[1])
        non_eating.append( (line[0].replace('fn=','').strip(','), s,e) )
    
    elif 'eating' in line:
        line=line.split()
        se=line[1].split('=')[1].split(',')
        s,e=int(se[0]),int(se[1])
        eating.append( (line[0].replace('fn=','').strip(','), s,e) )

# %%
eating
# Out:
# [('videos/eating1.mp4', 15, 115),
#  ('videos/eating3.mp4', 25, 150),
#  ('videos/eating4.mp4', 50, 150),
#  ('videos/eating4.mp4', 125, 225),
#  ('videos/eating4.mp4', 390, 450),
#  ('videos/eating5.mp4', 175, 250),
#  ('videos/eating5.mp4', 325, 400),
#  ('videos/eating5.mp4', 450, 550),
#  ('videos/eating7.mp4', 25, 100),
#  ('videos/mango.mp4', 75, 175),
#  ('videos/reading2.mp4', 25, 140),
#  ('videos/similar1.mp4', 0, 60),
#  ('videos/sitting.mp4', 300, 375),
#  ('videos/eating8.mp4', 90, 165),
#  ('videos/eating8.mp4', 790, 865),
#  ('videos/eating8.mp4', 1035, 1115),
#  ('videos/talking2.mp4', 525, 625)]

# %%
non_eating
# Out:
# [('videos/eating1.mp4', 240, 340),
#  ('videos/eating3.mp4', 175, 300),
#  ('videos/eating4.mp4', 250, 350),
#  ('videos/eating5.mp4', 550, 620),
#  ('videos/eating6.mp4', 0, 250),
#  ('videos/eating6.mp4', 250, 500),
#  ('videos/eating7.mp4', 200, 340),
#  ('videos/reading1.mp4', 0, 200),
#  ('videos/reading1.mp4', 200, 445),
#  ('videos/reading2.mp4', 250, 450),
#  ('videos/similar3.mp4', 0, 150),
#  ('videos/similar3.mp4', 150, 290),
#  ('videos/sitting.mp4', 0, 200),
#  ('videos/smartphone.mp4', 0, 250),
#  ('videos/talking.mp4', 0, 150),
#  ('videos/talking.mp4', 150, 300),
#  ('videos/talking.mp4', 300, 450),
#  ('videos/talking2.mp4', 0, 150)]

# %%
len(eating), len(non_eating), len(lines)
# Out:
# (17, 18, 35)

# %%
def extract_imgs(video_fn, skip_frames=1):
    video=cv2.VideoCapture(video_fn)
    imgs=[]
    frame_count=0
    while(video.isOpened()):
        ret, frame = video.read()
        if ret==False: break
        if frame_count%skip_frames==0:
            imgs.append(frame)
        frame_count+=1
    video.release() 
    return imgs

# %%
def view_imgs_as_video(imgs, delay=0.05):
    for img in imgs:
        clear_output(wait=True)
        plt.imshow(img[:,:,::-1])
        plt.show()
        time.sleep(delay)

# %%
fn, s,e=eating[0]
imgs=extract_imgs(fn)
action_imgs=imgs[s:e:5]
len(action_imgs)
# Out:
# 0

# %%
view_imgs_as_video(action_imgs)

# %%
pose = mp.solutions.pose.Pose(static_image_mode=False, min_detection_confidence=0.5, min_tracking_confidence=0.5)
def extract_keypoints(image_rgb): 
    try:
        results = pose.process(image_rgb)
        landmarks=results.pose_landmarks.landmark
    except Exception as e:
        # print('Error file=', fn)
        # print('Error=', e)
        return None
    xys=[]
    for landmark in landmarks:
        xys.append([landmark.x, landmark.y])
    xys=np.array(xys)
    return xys
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
actions=[]
for i, row in enumerate(eating):
    fn,s,e=row
    imgs=extract_imgs(fn)
    skip_frames=4
    if i==4 or i==11: skip_frames=3
    action_imgs= imgs[s:e:skip_frames]
    action=[]
    for img in action_imgs: 
        image_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        xys=extract_keypoints(image_rgb)
        xys=xys[:25].ravel() #first 25 keypoints
        action.append(xys)

    if len(action)==19:
        action.append(action[-1])
    action=action[:20]
    action=np.array(action)
    actions.append(action)
    

    print(fn, len(action))
# Out:
# videos/eating1.mp4 0
# videos/eating3.mp4 0
# videos/eating4.mp4 0
# videos/eating4.mp4 0
# videos/eating4.mp4 0
# videos/eating5.mp4 0
# videos/eating5.mp4 0
# videos/eating5.mp4 0
# videos/eating7.mp4 0
# videos/mango.mp4 0
# videos/reading2.mp4 0
# videos/similar1.mp4 0
# videos/sitting.mp4 0
# videos/eating8.mp4 0
# videos/eating8.mp4 0
# videos/eating8.mp4 0
# videos/talking2.mp4 0

# %%
X_eating=np.array(actions)
X_eating.shape
# Out:
# (17, 0)

# %%
actions_non=[]
for i, row in enumerate(non_eating):
    fn,s,e=row
    imgs=extract_imgs(fn)
    skip_frames=4
    if i==3: skip_frames=3
     
    action_imgs= imgs[s:e:skip_frames]
    action=[]
    for img in action_imgs: 
        image_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        xys=extract_keypoints(image_rgb)
        if xys is None: 
            print('Error file=', fn)
            continue
        xys=xys[:25].ravel() #first 25 keypoints
        action.append(xys)
    
    
    action=action[:20]
    action=np.array(action)
    actions_non.append(action)

    print(fn, len(action))
# Out:
# videos/eating1.mp4 0
# videos/eating3.mp4 0
# videos/eating4.mp4 0
# videos/eating5.mp4 0
# videos/eating6.mp4 0
# videos/eating6.mp4 0
# videos/eating7.mp4 0
# videos/reading1.mp4 0
# videos/reading1.mp4 0
# videos/reading2.mp4 0
# videos/similar3.mp4 0
# videos/similar3.mp4 0
# videos/sitting.mp4 0
# videos/smartphone.mp4 0
# videos/talking.mp4 0
# videos/talking.mp4 0
# videos/talking.mp4 0
# videos/talking2.mp4 0

# %%
X_not_eating=np.array(actions_non)
X_not_eating.shape
# Out:
# (18, 0)

# %%
X=np.concatenate((X_eating, X_not_eating))
X.shape
# Out:
# (35, 0)

# %%
y=np.array([1]*X_eating.shape[0]+[0]*X_not_eating.shape[0])
y.shape
# Out:
# (35,)

# %%
X=torch.from_numpy(X).float()
y=torch.from_numpy(y).reshape(-1,1)
X.shape, y.shape
# Out:
# (torch.Size([35, 0]), torch.Size([35, 1]))

# %%
ids=np.arange(X.shape[0])
np.random.shuffle(ids)
train_ids=ids[:int(len(ids)*0.8)]
test_ids=ids[int(len(ids)*0.8):]
X_train, y_train=X[train_ids], y[train_ids]
X_test, y_test=X[test_ids], y[test_ids]

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# (torch.Size([28, 0]),
#  torch.Size([28, 1]),
#  torch.Size([7, 0]),
#  torch.Size([7, 1]))

# %%
class LSTM(nn.Module):
    
    def __init__(self,input_dim,hidden_dim,output_dim,layer_num, seq_len):
        super(LSTM,self).__init__()
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        self.lstm = torch.nn.LSTM(input_dim,hidden_dim,layer_num,batch_first=True)
        self.fc = torch.nn.Linear(hidden_dim,output_dim)
        self.bn = nn.BatchNorm1d(seq_len)
        
    def forward(self,inputs):
        x = self.bn(inputs)
        lstm_out,(hn,cn) = self.lstm(x)
        out = self.fc(lstm_out[:,-1,:])
        return out

# %%
import random
n_data_size_train = X_train.shape[0]
n_data_size_test = X_test.shape[0]

def randomTrainingExampleBatch(batch_size,flag,num=-1):
    if flag == 'train':
        X = X_train
        y = y_train
        data_size = n_data_size_train
    elif flag == 'test':
        X = X_test
        y = y_test
        data_size = n_data_size_test
    if num == -1:
        ran_num = random.randint(0,data_size-batch_size)
    else:
        ran_num = num
    pose_sequence_tensor = X[ran_num:(ran_num+batch_size)]
    pose_sequence_tensor = pose_sequence_tensor
    category_tensor = y[ran_num:ran_num+batch_size,:]
    return category_tensor.long(),pose_sequence_tensor

# %%
n_hidden = 128
n_joints = 25*2
n_categories = 2
n_layer = 3
seq_len = 20
rnn = LSTM(n_joints,n_hidden,n_categories,n_layer, seq_len)
rnn.to(device)
# Out:
# LSTM(
#   (lstm): LSTM(50, 128, num_layers=3, batch_first=True)
#   (fc): Linear(in_features=128, out_features=2, bias=True)
#   (bn): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
learning_rate = 0.0005
optimizer = optim.SGD(rnn.parameters(),lr=learning_rate,momentum=0.9)
#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10000, gamma=0.1)

# %%
n_iters = 20000
print_every = 1000
plot_every = 1000
batch_size = 4

# Keep track of losses for plotting
current_loss = 0
all_losses = []

 
start = time.time()

for iter in range(1, n_iters + 1):
   
    category_tensor, input_sequence = randomTrainingExampleBatch(batch_size,'train')
    input_sequence = input_sequence.to(device)
    category_tensor = category_tensor.to(device)
    category_tensor = torch.squeeze(category_tensor)
    
    optimizer.zero_grad()
    
    output = rnn(input_sequence)
    loss = criterion(output, category_tensor)
    loss.backward()
    optimizer.step() 
 
    current_loss += loss.item()

    print('iter: %d, loss: %.3f' % (iter, loss.item()))
    
    
    # Add current loss avg to list of losses
    if iter % plot_every == 0:
        all_losses.append(current_loss / plot_every)
        current_loss = 0
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/ns/activity_recog/eating_data_load_lstm.ipynb Cell 30 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/home/ns/activity_recog/eating_data_load_lstm.ipynb#X41sZmlsZQ%3D%3D?line=17'>18</a> category_tensor = torch.squeeze(category_tensor)
#      <a href='vscode-notebook-cell:/home/ns/activity_recog/eating_data_load_lstm.ipynb#X41sZmlsZQ%3D%3D?line=19'>20</a> optimizer.zero_grad()
# ---> <a href='vscode-notebook-cell:/home/ns/activity_recog/eating_data_load_lstm.ipynb#X41sZmlsZQ%3D%3D?line=21'>22</a> output = rnn(input_sequence)
#      <a href='vscode-notebook-cell:/home/ns/activity_recog/eating_data_load_lstm.ipynb#X41sZmlsZQ%3D%3D?line=22'>23</a> loss = criterion(output, category_tensor)
#      <a href='vscode-notebook-cell:/home/ns/activity_recog/eating_data_load_lstm.ipynb#X41sZmlsZQ%3D%3D?line=23'>24</a> loss.backward()
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# /home/ns/activity_recog/eating_data_load_lstm.ipynb Cell 30 in LSTM.forward(self, inputs)
#      <a href='vscode-notebook-cell:/home/ns/activity_recog/eating_data_load_lstm.ipynb#X41sZmlsZQ%3D%3D?line=10'>11</a> def forward(self,inputs):
#      <a href='vscode-notebook-cell:/home/ns/activity_recog/eating_data_load_lstm.ipynb#X41sZmlsZQ%3D%3D?line=11'>12</a>     x = self.bn(inputs)
# ---> <a href='vscode-notebook-cell:/home/ns/activity_recog/eating_data_load_lstm.ipynb#X41sZmlsZQ%3D%3D?line=12'>13</a>     lstm_out,(hn,cn) = self.lstm(x)
#      <a href='vscode-notebook-cell:/home/ns/activity_recog/eating_data_load_lstm.ipynb#X41sZmlsZQ%3D%3D?line=13'>14</a>     out = self.fc(lstm_out[:,-1,:])
#      <a href='vscode-notebook-cell:/home/ns/activity_recog/eating_data_load_lstm.ipynb#X41sZmlsZQ%3D%3D?line=14'>15</a>     return out
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/rnn.py:810, in LSTM.forward(self, input, hx)
#     806     # Each batch of the hidden state should match the input sequence that
#     807     # the user believes he/she is passing in.
#     808     hx = self.permute_hidden(hx, sorted_indices)
# --> 810 self.check_forward_args(input, hx, batch_sizes)
#     811 if batch_sizes is None:
#     812     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     813                       self.dropout, self.training, self.bidirectional, self.batch_first)
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/rnn.py:730, in LSTM.check_forward_args(self, input, hidden, batch_sizes)
#     725 def check_forward_args(self,  # type: ignore[override]
#     726                        input: Tensor,
#     727                        hidden: Tuple[Tensor, Tensor],
#     728                        batch_sizes: Optional[Tensor],
#     729                        ):
# --> 730     self.check_input(input, batch_sizes)
#     731     self.check_hidden_size(hidden[0], self.get_expected_hidden_size(input, batch_sizes),
#     732                            'Expected hidden[0] size {}, got {}')
#     733     self.check_hidden_size(hidden[1], self.get_expected_cell_size(input, batch_sizes),
#     734                            'Expected hidden[1] size {}, got {}')
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/rnn.py:218, in RNNBase.check_input(self, input, batch_sizes)
#     214     raise RuntimeError(
#     215         'input must have {} dimensions, got {}'.format(
#     216             expected_input_dim, input.dim()))
#     217 if self.input_size != input.size(-1):
# --> 218     raise RuntimeError(
#     219         'input.size(-1) must be equal to input_size. Expected {}, got {}'.format(
#     220             self.input_size, input.size(-1)))
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 50, got 0

# %%
plt.plot(all_losses)

# %%
#test 

rnn.eval()

n_correct = 0
n_total = 0
for i in range(n_data_size_test):
    category_tensor, input_sequence = randomTrainingExampleBatch(1,'test',i)
    input_sequence = input_sequence.to(device)
    category_tensor = category_tensor.to(device)
    category_tensor = torch.squeeze(category_tensor)
    output = rnn(input_sequence)
    po=output.argmax(axis=1)
    guess=po.item()
    category = category_tensor
    if category == guess:
        n_correct += 1
    n_total += 1

print('Accuracy of %d test data: %.3f%%' % (n_data_size_test, n_correct / n_total * 100))
# Out:
# Accuracy of 7 test data: 57.143%

# %%
#test 
n_correct = 0
n_total = 0
for i in range(n_data_size_test):
    category_tensor, input_sequence = randomTrainingExampleBatch(1,'train',i)
    input_sequence = input_sequence.to(device)
    category_tensor = category_tensor.to(device)
    category_tensor = torch.squeeze(category_tensor)
    output = rnn(input_sequence)
    po=output.argmax(axis=1)
    guess=po.item()
    category = category_tensor
    if category == guess:
        n_correct += 1
    n_total += 1

print('Accuracy of %d test data: %.3f%%' % (n_data_size_test, n_correct / n_total * 100))
# Out:
# Accuracy of 7 test data: 100.000%

# %% [markdown]
# ### load a video and predict

# %%
fn, s,e=eating[3]
fn, s,e=non_eating[5]
imgs=extract_imgs(fn)
action_imgs=imgs[s:e:5]
len(action_imgs)
# Out:
# 50

# %%
view_imgs_as_video(action_imgs)

# %%
action=[]
for img in action_imgs: 
    image_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    xys=extract_keypoints(image_rgb)
    xys=xys[:25].ravel()
    action.append(xys)
action=np.array(action)[:20]
action.shape
# Out:
# (20, 50)

# %%
tx=torch.from_numpy(action).float()
tx=tx.unsqueeze(0).to(device)
tx.shape
# Out:
# torch.Size([1, 20, 50])

# %%
output = rnn(tx).cpu().detach().numpy()
po=output.argmax(axis=1)
prediction=po[0]
print('prediction=', prediction)
# Out:
# prediction= 0

# %%
fn='eat_output.avi' 

video=cv2.VideoCapture(fn)
imgs=[]
while(video.isOpened()):
    ret, frame = video.read()
    if ret==False: break
    imgs.append(frame)
video.release() 

len(imgs)
# Out:
# 412

# %%
def extract_imgs(video_fn, skip_frames=1):
    video=cv2.VideoCapture(video_fn)
    imgs=[]
    frame_count=0
    while(video.isOpened()):
        ret, frame = video.read()
        if ret==False: break
        if frame_count%skip_frames==0:
            imgs.append(frame)
        frame_count+=1
    video.release() 
    return imgs

# %%
imgs=extract_imgs(fn, skip_frames=4)
len(imgs)
# Out:
# 103

# %%
for img in imgs[22:42]:
    img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.show()
    time.sleep(0.1)
    clear_output(wait=True)

# %%
action=[]
for img in imgs[22:42]: 
    image_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    xys=extract_keypoints(image_rgb)
    xys=xys[:25].ravel() #first 25 keypoints
    action.append(xys)
action=np.array(action)
action.shape
# Out:
# (20, 50)

# %%
tx=torch.from_numpy(action).float()
tx=tx.unsqueeze(0).to(device)
tx.shape
# Out:
# torch.Size([1, 20, 50])

# %%
tx=torch.from_numpy(action).float()
tx=tx.unsqueeze(0).to(device)
tx.shape
# Out:
# torch.Size([1, 20, 50])

# %%
output = rnn(tx).cpu().detach().numpy()
po=output.argmax(axis=1)
prediction=po[0]
print('prediction=', prediction)
# Out:
# prediction= 1

# %% [markdown]
# ### live video

# %%
from collections import deque

labels=['non-eating', 'eating']

# %%
def draw_points25(image, xys, keys=None):
    mp_drawing = mp.solutions.drawing_utils
    drawing_spec = mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2)
 
    if keys==None: keys=[ i for i in range(25) ]
    
    xs,ys=xys[:25], xys[25:]
    for key in keys:
        x,y= xs[key], ys[key]
        x_px, y_px = int(x * image.shape[1]), int(y * image.shape[0])
        cv2.circle(image, (x_px, y_px), drawing_spec.circle_radius, drawing_spec.color, drawing_spec.thickness)
    return image

# %%
image=draw_points25(image_rgb.copy(), xys)
plt.imshow(image)

# %%
xys.shape
# Out:
# (50,)

# %%
vid = cv2.VideoCapture(0)

# maintain a running queue fo 20 frames
kps= deque(maxlen=20)

# frames=[]
skip_frames=4
frame_count=0
seq_len=20

while(True):
      
    ret, frame = vid.read()
    if ret==False: 
        print('no frame')
        continue

    # cv2.imshow('frame', frame)

    image_rgb=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    xys=extract_keypoints(image_rgb)
    xys=xys[:25].ravel() #first 25 keypoints
    frame=draw_points25(frame, xys)

    frame_count+=1
    if frame_count%skip_frames==0:
        # image_rgb=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # xys=extract_keypoints(image_rgb)
        # xys=xys[:25].ravel() #first 25 keypoints
        kps.append(xys)

        frame_count=0

        # frame=draw_points25(frame, xys)
        # plt.imshow(image)
    
    if len(kps)==seq_len:
        # print('predicting...')
        action=np.array(kps)
        tx=torch.from_numpy(action).float()
        tx=tx.unsqueeze(0).to(device)
        output = rnn(tx).cpu().detach().numpy()
        po=output.argmax(axis=1)
        prediction=po[0]
        # print('prediction=', prediction)

        #draw text on the image
        font = cv2.FONT_HERSHEY_SIMPLEX
        org = (50, 50)
        fontScale = 1
        color = (255, 0, 0)
        thickness = 2
        frame = cv2.putText(frame, "pred="+labels[prediction], org, font,  
                   fontScale, color, thickness, cv2.LINE_AA)
    
    cv2.imshow('frame', frame)


    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
  

vid.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)

# %%
len(frames)
# Out:
# 20

# %%
vid.release()
cv2.destroyAllWindows()

# %%
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# %%
cap = cv2.VideoCapture(0)


kps= deque(maxlen=20)

# frames=[]
skip_frames=4
frame_count=0
seq_len=20


while cap.isOpened():
     # read frame
     _, frame = cap.read()
     try:
          # resize the frame for portrait video
          # frame = cv2.resize(frame, (350, 600))
          # convert to RGB
          frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

          # process the frame for pose detection
          pose_results = pose.process(frame_rgb)
          landmarks=pose_results.pose_landmarks.landmark
          landmarks=landmarks[:25]


          frame_count+=1
          if frame_count%skip_frames==0:
               xys=[]
               for landmark in landmarks:
                    xys.append([landmark.x, landmark.y])
               xys=np.array(xys).ravel()
               # xys=xys[:25].ravel() #first 25 keypoints
               kps.append(xys) 
               frame_count=0
    
          if len(kps)==seq_len:
               # print('predicting...')
               action=np.array(kps)
               tx=torch.from_numpy(action).float()
               tx=tx.unsqueeze(0).to(device)
               output = rnn(tx).cpu().detach().numpy()
               po=output.argmax(axis=1)
               prediction=po[0]
               # print('prediction=', prediction)

               #draw text on the image
               font = cv2.FONT_HERSHEY_SIMPLEX
               org = (50, 50)
               fontScale = 1
               color = (255, 0, 0)
               thickness = 2
               frame = cv2.putText(frame, "pred="+labels[prediction], org, font,  
                         fontScale, color, thickness, cv2.LINE_AA)
               


          # draw skeleton on the frame
          mp_drawing.draw_landmarks(frame, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
          # display the frame
          cv2.imshow('Output', frame)
     except Exception as e:
          print(e)
          break

     if cv2.waitKey(1) == ord('q'):
          break
          
cap.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)
#
# QObject::moveToThread: Current thread (0x55c3a59e48f0) is not the object's thread (0x55c3a5de7780).
# Cannot move to target thread (0x55c3a59e48f0)

# %%
landmarks[:25]
# Out:
# [x: 0.52103590965271
#  y: 0.47297918796539307
#  z: -1.4330254793167114
#  visibility: 0.9998156428337097,
#  x: 0.540941596031189
#  y: 0.41173654794692993
#  z: -1.4378283023834229
#  visibility: 0.99962317943573,
#  x: 0.555451512336731
#  y: 0.41096705198287964
#  z: -1.4375041723251343
#  visibility: 0.9994373917579651,
#  x: 0.5688691139221191
#  y: 0.4094174802303314
#  z: -1.4381498098373413
#  visibility: 0.9995567798614502,
#  x: 0.49588173627853394
#  y: 0.4049997627735138
#  z: -1.4451009035110474
#  visibility: 0.999733567237854,
#  x: 0.4736701548099518
#  y: 0.39938417077064514
#  z: -1.4453051090240479
#  visibility: 0.9997055530548096,
#  x: 0.4523293972015381
#  y: 0.3945474326610565
#  z: -1.4452706575393677
#  visibility: 0.9997961521148682,
#  x: 0.5758994817733765
#  y: 0.3987061083316803
#  z: -1.184613585472107
#  visibility: 0.9995002746582031,
#  x: 0.40697574615478516
#  y: 0.38426944613456726
#  z: -1.2058160305023193
#  visibility: 0.999832272529602,
#  x: 0.5307180881500244
#  y: 0.522601306438446
#  z: -1.3147947788238525
#  visibility: 0.9998860359191895,
#  x: 0.4785539209842682
#  y: 0.5181268453598022
#  z: -1.320097804069519
#  visibility: 0.9999513030052185,
#  x: 0.6655386090278625
#  y: 0.5866077542304993
#  z: -0.8782498240470886
#  visibility: 0.99908447265625,
#  x: 0.2684694230556488
#  y: 0.5978243350982666
#  z: -0.9112118482589722
#  visibility: 0.999774694442749,
#  x: 0.8750397562980652
#  y: 0.9421183466911316
#  z: -0.7207293510437012
#  visibility: 0.920239269733429,
#  x: 0.13880763947963715
#  y: 0.9454091191291809
#  z: -0.7583716511726379
#  visibility: 0.9050552845001221,
#  x: 0.9722857475280762
#  y: 1.2658040523529053
#  z: -0.8097329139709473
#  visibility: 0.3970690071582794,
#  x: 0.057420022785663605
#  y: 1.3104140758514404
#  z: -0.9346316456794739
#  visibility: 0.4709281325340271,
#  x: 1.0211318731307983
#  y: 1.3460322618484497
#  z: -0.8606964349746704
#  visibility: 0.2862837016582489,
#  x: 0.015315577387809753
#  y: 1.3956483602523804
#  z: -0.9841201901435852
#  visibility: 0.3827918767929077,
#  x: 0.9954752922058105
#  y: 1.3713877201080322
#  z: -0.9347577095031738
#  visibility: 0.3647767901420593,
#  x: 0.04648744687438011
#  y: 1.3992455005645752
#  z: -1.0861785411834717
#  visibility: 0.4763018488883972,
#  x: 0.9577034711837769
#  y: 1.351807951927185
#  z: -0.8457948565483093
#  visibility: 0.4001157283782959,
#  x: 0.07643081992864609
#  y: 1.3718390464782715
#  z: -0.9808177947998047
#  visibility: 0.4819241464138031,
#  x: 0.5937321186065674
#  y: 1.1434460878372192
#  z: -0.03702221065759659
#  visibility: 0.03966718912124634,
#  x: 0.36515265703201294
#  y: 1.1535890102386475
#  z: 0.03851062059402466
#  visibility: 0.047628842294216156]
